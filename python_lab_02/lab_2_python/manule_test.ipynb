# %%
from shape import Shape2D

from circle import Circle
from rectangle import Rectangle

circle1 = Circle(0, 0, 1)
circle2 = Circle(1, 1, 1)
rectangle = Rectangle(0, 0, 1, 1)

print(circle1 == circle2) # True, same area
print(circle1 == rectangle) # False
circle1.translate(5, 3)
circle3 = Circle(radius=3)
print(circle3 >= circle1) # True
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from circle import Circle
#       2 from rectangle import Rectangle
#       4 circle1 = Circle(0, 0, 1)
#
# File ~/Documents/github/first_python_lab_ED25/python_lab_02/lab_2_python/circle.py:2
#       1 import math
# ----> 2 from shape import Shape2d
#       4 class Circle(Shape2d):
#       6     def __init__(self, x: float = 0, y: float = 0, radius: float = 1 ):
#
# ImportError: cannot import name 'Shape2d' from 'shape' (/Users/lillmossi/Documents/github/first_python_lab_ED25/python_lab_02/lab_2_python/shape.py)
